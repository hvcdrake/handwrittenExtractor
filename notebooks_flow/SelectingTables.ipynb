# %%
import pandas as pd

# %%
local = pd.read_csv('local_result/result.csv')

# %%
local.head(9)
# Out:
#                              NombreArchivo  idCupon        DNI  \
# 0      MarzoCompras_0202072019164448_00043     1000  672658937
# 1      MarzoCompras_0202072019164503_00537     1001   80552369
# 2      MarzoCompras_0202072019164503_00546     1002       6650
# 3      MarzoCompras_0202072019164511_00837     1003  424475467
# 4  MarzoCompras_EL_B3_20190705154148_00762     1004   47744774
# 5  MarzoCompras_EL_B3_20190705154149_00798     1005    9900757
# 6  MarzoCompras_LV_B2_20190704151228_00879     1006   23849537
# 7  MarzoCompras_MD_B5_20190709165132_00965     1007   70605766
# 8  MarzoCompras_XM_B5_20190710113243_01121     1008   42210749
#
#    AcertividadDNI    Telefono  AcertividadTelefono  idCampania  idUsuario  \
# 0            0.00   777257672                91.85           4          1
# 1           89.50     2726244                98.01           4          1
# 2            0.00     9453881                73.68           4          1
# ...

# %%
azure = pd.read_csv('azure_result/azure_result.csv')

# %%
azure.head()
# Out:
#                              NombreArchivo  idCupon         DNI  \
# 0      MarzoCompras_0202072019164448_00043     1000  42650934.0
# 1      MarzoCompras_0202072019164503_00537     1001  40557762.0
# 2      MarzoCompras_0202072019164503_00546     1002   8642202.0
# 3      MarzoCompras_0202072019164511_00837     1003         NaN
# 4  MarzoCompras_EL_B3_20190705154148_00762     1004   4714974.0
#
#    AcertividadDNI   Telefono  AcertividadTelefono              NombreCompleto  \
# 0       85.714286  977784672            85.714286  Blaudi Idali Raja Revilla.
# 1       90.000000  927136744            85.000000
# 2       87.916667  995382267            87.916667     CAROLINA Cde los MERINO
# 3        0.000000   98083440            86.666667  JACK cline Min DOa BEcerra
# 4       85.000000  953065112            86.666667          Mizer SiLUA medina
#
#    AcertividadNombreCompleto                                   Direccion  \
# ...
